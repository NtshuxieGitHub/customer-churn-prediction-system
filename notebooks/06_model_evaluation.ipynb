# %% [markdown]
# **1. Model Evaluation:**

# %%
# Import dependencies
import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath(os.path.join('..')))

# Import the collect_data function
from src.data_collection import collect_data

# import the clean_data function
from src.data_cleaning import clean_data

# Run collect_data function
data, _, _, _, _, _, _, _, _  = collect_data()

# Run clean_data function
data_cleaned = clean_data(data)

# Run encode_labels function
from src.data_processing import encode_labels
data_encoded = encode_labels(data_cleaned)

# Splitting features and target columns
from src.train_test_split import split_data
X, Y = split_data(data_encoded)

# Splitting features and target columns
from src.train_test_split import split_train_test_data
X_train, X_test, Y_train, Y_test = split_train_test_data(X, Y)

# Import handle_target_imbalance
from src.data_processing import handle_target_imbalance
X_train, Y_train = handle_target_imbalance(X_train, Y_train)

# Train and cross validate models
from src.model_training import default_param_training
cv_results = default_param_training(X_train, Y_train)

# Train models and cross validate models with hyperparameter tuning
from src.model_training import tuning_and_best_model_selection
results, mdl = tuning_and_best_model_selection(X_train, Y_train)

from src.model_training import fit_model
mdl = fit_model(X_train, Y_train, mdl)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Evaluate model on test data
from src.model_evaluation import evaluate_model
# Model evaluation
predictions, accuracy, cm, cr = evaluate_model(X_test, Y_test, mdl)
# Out:
# Accuracy Score:
#  0.7764371894960965
# Confusion Matrix:
#  [[868 168]
#  [147 226]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      1036
#            1       0.57      0.61      0.59       373
#
#     accuracy                           0.78      1409
#    macro avg       0.71      0.72      0.72      1409
# weighted avg       0.78      0.78      0.78      1409

# %%
accuracy
# Out:
# 0.7764371894960965

# %%
cm
# Out:
# array([[868, 168],
#        [147, 226]], dtype=int64)

# %%
cr
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.86      0.84      0.85      1036\n           1       0.57      0.61      0.59       373\n\n    accuracy                           0.78      1409\n   macro avg       0.71      0.72      0.72      1409\nweighted avg       0.78      0.78      0.78      1409\n'

# %% [markdown]
# **2. Save Model:**

# %%
from src.save_model import save_trained_mdl
save_trained_mdl(mdl, X)

# %% [markdown]
# **3. Load saved model and build a predictive system:**

# %%
# Load saved model and build a predictive system
from src.load_model import load_model
mdl, features = load_model()

# %%
mdl
# Out:
# RandomForestClassifier(min_samples_split=5, random_state=42)

# %%
features
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges']

# %%
# Make a prediction
data_dict = {
    "gender": "Female",
    "SeniorCitizen": 0,
    "Partner": "Yes",
    "Dependents": "No",
    "tenure": "1",
    "PhoneService": "No",
    "MultipleLines": "No phone service",
    "InternetService": "DSL",
    "OnlineSecurity": "No",
    "OnlineBackup": "Yes",
    "DeviceProtection": "No",
    "TechSupport": "No",
    "StreamingTV": "No",
    "StreamingMovies": "No",
    "Contract": "Month-to-month",
    "PaperlessBilling": "Yes",
    "PaymentMethod": "Electronic check",
    "MonthlyCharges": 29.85,
    "TotalCharges": 29.85
}

# Creat a df of the data
import pandas as pd
df = pd.DataFrame(data_dict, index=[0])
df
# Out:
#    gender SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  Female             0     Yes         No      1           No
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod MonthlyCharges TotalCharges
# 0              Yes  Electronic check          29.85        29.85

# %%
df.to_csv('../data/raw/test_data.csv', index=False)

# %% [markdown]
# **Insights:**
#
# 1. Model evaluated
# 2. Trained model saved
# 3. Loading model and features
# 4. Creating test set for a single customer prediction
