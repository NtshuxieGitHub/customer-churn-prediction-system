# %% [markdown]
# **2. Predictive System Testings:**

# %%
# Import dependencies
import sys
import os

# Add the src directory to the system path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# Run prediction system
from predictive_system import run_predictive_system
run_predictive_system()
# Out:
# ('Customer will not churn.', array([[0.56890873, 0.43109127]]))

# %% [markdown]
# **Insights:**
#
# 1. Predictive system return prediction with probability value
